# %%
import pandas as pd

# %%
inter_sig = {27140, 41480, 29200, 30230, 28185, 11290, 47130, 41500, 46110, 27170, 28710, 28200, 11305, 48170, 47150, 46130, 11320, 27710, 47170, 46150, 45130, 28237, 41550, 48720, 45140, 28245, 47190, 26710, 26200, 11350, 48730, 46170, 48220, 27230, 41570, 48740, 28260, 47210, 48240, 47730, 11380, 41590, 26230, 46710, 44150, 43130, 48250, 45180, 47230, 42110, 45190, 41610, 48270, 45710, 43150, 42130, 47250, 11410, 44180, 46230, 45720, 47770, 27290, 45210, 41630, 44710, 44200, 47280, 11440, 41650, 46770, 48820, 44210, 48310, 42170, 47290, 46780, 41150, 46790, 44230, 48840, 43720, 48330, 45770, 47820, 42190, 11470, 46800, 43730, 47830, 44760, 46810, 44250, 43740, 45790, 42720, 47840, 42210, 44770, 46820, 41190, 48870, 45800, 43750, 42730, 47850, 11500, 26350, 46830, 48880, 43760, 42230, 46840, 48890, 41210, 43770, 42750, 44800, 41730, 41220, 11530, 44810, 26380, 46860, 42770, 46870, 11545, 42780, 47900, 44830, 46880, 41250, 11560, 26410, 46890, 42800, 47920, 46900, 42810, 47930, 46910, 42820, 11590, 26440, 41820, 41310, 11620, 26470, 11110, 11650, 26500, 11140, 31110, 41360, 41370, 30110, 11680, 26530, 11170, 31140, 41390, 29110, 30140, 11710, 11200, 41410, 31170, 28110, 11215, 29140, 41430, 30170, 11740, 11230, 31710, 31200, 29155, 41450, 29170, 30200, 11260, 26110}

# %%
inter_sig = list(inter_sig)

# %%
inter_sig
# Out:
# [27140,
#  41480,
#  29200,
#  30230,
#  28185,
#  11290,
#  47130,
#  41500,
#  46110,
#  27170,
#  28710,
#  28200,
#  11305,
#  48170,
#  47150,
#  46130,
#  11320,
#  27710,
#  47170,
#  46150,
#  45130,
#  28237,
#  41550,
#  48720,
#  45140,
#  28245,
#  47190,
#  26710,
#  26200,
#  11350,
#  48730,
#  46170,
#  48220,
#  27230,
#  41570,
#  48740,
#  28260,
#  47210,
#  48240,
#  47730,
#  11380,
#  41590,
#  26230,
#  46710,
#  44150,
#  43130,
#  48250,
#  45180,
#  47230,
#  42110,
#  45190,
#  41610,
#  48270,
#  45710,
#  43150,
#  42130,
#  47250,
#  11410,
#  44180,
#  46230,
#  45720,
#  47770,
#  27290,
#  45210,
#  41630,
#  44710,
#  44200,
#  47280,
#  11440,
#  41650,
#  46770,
#  48820,
#  44210,
#  48310,
#  42170,
#  47290,
#  46780,
#  41150,
#  46790,
#  44230,
#  48840,
#  43720,
#  48330,
#  45770,
#  47820,
#  42190,
#  11470,
#  46800,
#  43730,
#  47830,
#  44760,
#  46810,
#  44250,
#  43740,
#  45790,
#  42720,
#  47840,
#  42210,
#  44770,
#  46820,
# ...

# %%
len(inter_sig)
# Out:
# 182

# %%
def sortbaby(df, sigidx, intersection):
    
    #변수설정
    df_sig = list(df.iloc[:,sigidx])
    del_list = []
    column_name = df.columns[sigidx]
    #없애보자
    for i, sig in enumerate(df_sig):
        if sig in intersection:
            print(sig)
            pass
        else:
            del_list.append(i)
    drop_data = df.drop(del_list, axis=0)
    drop_data = drop_data.drop_duplicates(subset=column_name)
    print(len(del_list))
    #drop_data를 sigidx기준으로 정렬
    sorted_df = drop_data.sort_values(by=column_name)
    
    return sorted_df

# %%
df1 = pd.read_csv('/Users/phr/Desktop/BigTeam/big_final/data/표준화데이터.csv', encoding='utf-8')

# %%
df1
# Out:
#      Unnamed: 0  진짜 구급차 출동시간 표준화  기대수명 표준화  병원수 표준화  보건시설 표준화   구급차 표준화  \
# 0             0         1.000000  0.708333    0.125  0.087670  0.384615
# 1             1         1.000000  0.716346    0.100  0.049388  0.230769
# 2             2         1.000000  0.767628    0.050  0.281052  0.307692
# 3             3         1.000000  0.719551    0.125  0.258234  0.153846
# 4             4         1.000000  0.674679    0.125  0.219497  0.307692
# ..          ...              ...       ...      ...       ...       ...
# 177         177         0.853260  0.084936    0.025  0.719289  0.230769
# 178         178         0.764298  0.213141    0.000  0.712201  0.230769
# 179         179         0.851839  0.278846    0.000  0.621840  0.307692
# 180         180         0.845561  0.376603    0.050  0.545313  0.307692
# 181         181         0.713657  0.125000    0.000  0.691885  0.384615
#
#       의사수 표준화  지방소멸지수 표준화  Unnamed: 8
# 0    1.000000    0.533190         NaN
# ...

# %%
df2 = pd.read_csv('/Users/phr/Desktop/BigTeam/big_final/data/찐3대중증사망.csv', encoding='cp949')

# %%
df2
# Out:
#         시군구명    시군구코드  Unnamed: 2  순환계통 사망자 수  순환계통 10만명당 사망률  \
# 0    강원도 강릉시  42150.0         NaN       335.0           158.1
# 1    강원도 고성군  42820.0         NaN        78.0           290.6
# 2    강원도 동해시  42170.0         NaN       120.0           133.7
# 3    강원도 삼척시  42230.0         NaN       119.0           186.2
# 4    강원도 속초시  42210.0         NaN       122.0           148.5
# ..       ...      ...         ...         ...             ...
# 295      NaN      NaN         NaN         NaN             NaN
# 296      NaN      NaN         NaN         NaN             NaN
# 297      NaN      NaN         NaN         NaN             NaN
# 298      NaN      NaN         NaN         NaN             NaN
# 299      NaN      NaN         NaN         NaN             NaN
#
#      순환계통 연령 표준화 사망률(10만명당)  운수사고 사망자 수  운수사고 10만명당 사망률  \
# 0                      52.8        19.0             9.0
# 1                      68.4         3.0            11.2
# ...

# %%
df2 = df2.dropna(subset=['시군구코드'])

# %%
df2
# Out:
#              시군구명    시군구코드  Unnamed: 2  순환계통 사망자 수  순환계통 10만명당 사망률  \
# 0         강원도 강릉시  42150.0         NaN       335.0           158.1
# 1         강원도 고성군  42820.0         NaN        78.0           290.6
# 2         강원도 동해시  42170.0         NaN       120.0           133.7
# 3         강원도 삼척시  42230.0         NaN       119.0           186.2
# 4         강원도 속초시  42210.0         NaN       122.0           148.5
# ..            ...      ...         ...         ...             ...
# 241      충청북도 증평군  43745.0         NaN        47.0           128.9
# 242      충청북도 진천군  43750.0         NaN       111.0           132.0
# 243  충청북도 청주시 상당구  43111.0         NaN       224.0           117.3
# 244  충청북도 청주시 흥덕구  43113.0         NaN       177.0            66.7
# 245      충청북도 충주시  43130.0         NaN       302.0           144.7
#
#      순환계통 연령 표준화 사망률(10만명당)  운수사고 사망자 수  운수사고 10만명당 사망률  \
# 0                      52.8        19.0             9.0
# ...

# %%
df2['시군구코드'] = df2['시군구코드'].astype(int)
# Out:
# /var/folders/q4/msgrrlw53plcx_prs66xy2n40000gn/T/ipykernel_25304/3759866608.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['시군구코드'] = df2['시군구코드'].astype(int)

# %%
df2
# Out:
#              시군구명  시군구코드  Unnamed: 2  순환계통 사망자 수  순환계통 10만명당 사망률  \
# 0         강원도 강릉시  42150         NaN       335.0           158.1
# 1         강원도 고성군  42820         NaN        78.0           290.6
# 2         강원도 동해시  42170         NaN       120.0           133.7
# 3         강원도 삼척시  42230         NaN       119.0           186.2
# 4         강원도 속초시  42210         NaN       122.0           148.5
# ..            ...    ...         ...         ...             ...
# 241      충청북도 증평군  43745         NaN        47.0           128.9
# 242      충청북도 진천군  43750         NaN       111.0           132.0
# 243  충청북도 청주시 상당구  43111         NaN       224.0           117.3
# 244  충청북도 청주시 흥덕구  43113         NaN       177.0            66.7
# 245      충청북도 충주시  43130         NaN       302.0           144.7
#
#      순환계통 연령 표준화 사망률(10만명당)  운수사고 사망자 수  운수사고 10만명당 사망률  \
# 0                      52.8        19.0             9.0
# 1                      68.4         3.0            11.2
# ...

# %%
df3 = sortbaby(df2, 1, inter_sig)
# Out:
# 42820
# 42170
# 42230
# 42210
# 42800
# 42750
# 42130
# 42810
# 42770
# 42780
# 42110
# 42190
# 42720
# 42730
# 41820
# 41210
# 41610
# 41310
# 41410
# 41570
# 41360
# 41250
# 41190
# 41390
# 41550
# 41630
# 41730
# 41370
# 41430
# 41150
# 41500
# 41480
# 41220
# 41650
# 41450
# 41590
# 48310
# 48880
# 48820
# 48250
# 48840
# 48270
# 48240
# 48330
# 48720
# 48170
# 48170
# 48740
# 48220
# 48730
# 48870
# 48890
# 47290
# 47130
# 47830
# 47190
# 47150
# 47280
# 47920
# 47250
# 47840
# 47170
# 47770
# 47210
# 47230
# 47900
# 47930
# 47730
# 47820
# 47850
# 29200
# 29155
# 29110
# 29170
# 29140
# 27290
# 27710
# 27140
# 27230
# 27170
# 30230
# 30110
# 30170
# 30200
# 30140
# 26440
# 26410
# 26710
# 26230
# 26530
# 26380
# 26500
# 26470
# 26200
# 26110
# 26350
# 11680
# 11740
# 11305
# 11500
# 11620
# 11215
# 11530
# 11545
# 11350
# 11320
# 11230
# 11590
# 11440
# 11410
# 11650
# 11200
# 11290
# 11710
# 11470
# 11560
# 11170
# 11380
# 11110
# 11140
# 11260
# 31140
# 31170
# 31200
# 31710
# ...

# %%
df3
# Out:
#           시군구명  시군구코드  Unnamed: 2  순환계통 사망자 수  순환계통 10만명당 사망률  \
# 160  서울특별시 종로구  11110         NaN       229.0           160.4
# 161   서울특별시 중구  11140         NaN       194.0           161.1
# 158  서울특별시 용산구  11170         NaN       247.0           113.1
# 153  서울특별시 성동구  11200         NaN       242.0            84.8
# 143  서울특별시 광진구  11215         NaN       337.0            99.4
# ..         ...    ...         ...         ...             ...
# 60    경상남도 고성군  48820         NaN       179.0           353.4
# 62    경상남도 남해군  48840         NaN       155.0           365.6
# 78    경상남도 함양군  48870         NaN       142.0           369.4
# 59    경상남도 거창군  48880         NaN       154.0           252.5
# 79    경상남도 합천군  48890         NaN       172.0           399.0
#
#      순환계통 연령 표준화 사망률(10만명당)  운수사고 사망자 수  운수사고 10만명당 사망률  \
# 160                    64.5         7.0             4.9
# 161                    64.8         4.0             3.3
# ...

# %%
df3.columns
# Out:
# Index(['시군구명', '시군구코드', 'Unnamed: 2', '순환계통 사망자 수', '순환계통 10만명당 사망률',
#        '순환계통 연령 표준화 사망률(10만명당)', '운수사고 사망자 수', '운수사고 10만명당 사망률',
#        '운수사고 연령 표준화 사망률(10만명당)', '낙상 사망자수  ', '낙상 10만명당 사망률',
#        '낙상 연령 표준화 사망률(10만명당)', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19'],
#       dtype='object')

# %%
df3['지역별중증사망수치'] = df3['순환계통 10만명당 사망률']+df3['운수사고 10만명당 사망률']+df3['낙상 10만명당 사망률']

# %%
df3
# Out:
#           시군구명  시군구코드  Unnamed: 2  순환계통 사망자 수  순환계통 10만명당 사망률  \
# 160  서울특별시 종로구  11110         NaN       229.0           160.4
# 161   서울특별시 중구  11140         NaN       194.0           161.1
# 158  서울특별시 용산구  11170         NaN       247.0           113.1
# 153  서울특별시 성동구  11200         NaN       242.0            84.8
# 143  서울특별시 광진구  11215         NaN       337.0            99.4
# ..         ...    ...         ...         ...             ...
# 60    경상남도 고성군  48820         NaN       179.0           353.4
# 62    경상남도 남해군  48840         NaN       155.0           365.6
# 78    경상남도 함양군  48870         NaN       142.0           369.4
# 59    경상남도 거창군  48880         NaN       154.0           252.5
# 79    경상남도 합천군  48890         NaN       172.0           399.0
#
#      순환계통 연령 표준화 사망률(10만명당)  운수사고 사망자 수  운수사고 10만명당 사망률  \
# 160                    64.5         7.0             4.9
# 161                    64.8         4.0             3.3
# ...

# %%
df1['지역별중증사망수치'] = df3['지역별중증사망수치']

# %%
df1
# Out:
#      Unnamed: 0  진짜 구급차 출동시간 표준화  기대수명 표준화  병원수 표준화  보건시설 표준화   구급차 표준화  \
# 0             0         1.000000  0.708333    0.125  0.087670  0.384615
# 1             1         1.000000  0.716346    0.100  0.049388  0.230769
# 2             2         1.000000  0.767628    0.050  0.281052  0.307692
# 3             3         1.000000  0.719551    0.125  0.258234  0.153846
# 4             4         1.000000  0.674679    0.125  0.219497  0.307692
# ..          ...              ...       ...      ...       ...       ...
# 177         177         0.853260  0.084936    0.025  0.719289  0.230769
# 178         178         0.764298  0.213141    0.000  0.712201  0.230769
# 179         179         0.851839  0.278846    0.000  0.621840  0.307692
# 180         180         0.845561  0.376603    0.050  0.545313  0.307692
# 181         181         0.713657  0.125000    0.000  0.691885  0.384615
#
#       의사수 표준화  지방소멸지수 표준화  Unnamed: 8  지역별중증사망수치
# 0    1.000000    0.533190         NaN        NaN
# ...

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', '진짜 구급차 출동시간 표준화', '기대수명 표준화', '병원수 표준화', '보건시설 표준화',
#        '구급차 표준화', '의사수 표준화', '지방소멸지수 표준화', 'Unnamed: 8', '지역별중증사망수치'],
#       dtype='object')

# %%
df1 = df1.drop('Unnamed: 0', axis=1)

# %%
df1 = df1.drop('Unnamed: 8', axis=1)

# %%
df1
# Out:
#      진짜 구급차 출동시간 표준화  기대수명 표준화  병원수 표준화  보건시설 표준화   구급차 표준화   의사수 표준화  \
# 0           1.000000  0.708333    0.125  0.087670  0.384615  1.000000
# 1           1.000000  0.716346    0.100  0.049388  0.230769  0.457711
# 2           1.000000  0.767628    0.050  0.281052  0.307692  0.129353
# 3           1.000000  0.719551    0.125  0.258234  0.153846  0.129353
# 4           1.000000  0.674679    0.125  0.219497  0.307692  0.139303
# ..               ...       ...      ...       ...       ...       ...
# 177         0.853260  0.084936    0.025  0.719289  0.230769  0.039801
# 178         0.764298  0.213141    0.000  0.712201  0.230769  0.034826
# 179         0.851839  0.278846    0.000  0.621840  0.307692  0.039801
# 180         0.845561  0.376603    0.050  0.545313  0.307692  0.049751
# 181         0.713657  0.125000    0.000  0.691885  0.384615  0.059701
#
#      지방소멸지수 표준화  지역별중증사망수치
# 0      0.533190        NaN
# 1      0.554715      305.5
# 2      0.664849      149.3
# ...

# %%
df3
# Out:
#           시군구명  시군구코드  Unnamed: 2  순환계통 사망자 수  순환계통 10만명당 사망률  \
# 160  서울특별시 종로구  11110         NaN       229.0           160.4
# 161   서울특별시 중구  11140         NaN       194.0           161.1
# 158  서울특별시 용산구  11170         NaN       247.0           113.1
# 153  서울특별시 성동구  11200         NaN       242.0            84.8
# 143  서울특별시 광진구  11215         NaN       337.0            99.4
# ..         ...    ...         ...         ...             ...
# 60    경상남도 고성군  48820         NaN       179.0           353.4
# 62    경상남도 남해군  48840         NaN       155.0           365.6
# 78    경상남도 함양군  48870         NaN       142.0           369.4
# 59    경상남도 거창군  48880         NaN       154.0           252.5
# 79    경상남도 합천군  48890         NaN       172.0           399.0
#
#      순환계통 연령 표준화 사망률(10만명당)  운수사고 사망자 수  운수사고 10만명당 사망률  \
# 160                    64.5         7.0             4.9
# 161                    64.8         4.0             3.3
# ...

# %%
df3 = df3.reset_index()

# %%
df3
# Out:
#      index       시군구명  시군구코드  Unnamed: 2  순환계통 사망자 수  순환계통 10만명당 사망률  \
# 0      160  서울특별시 종로구  11110         NaN       229.0           160.4
# 1      161   서울특별시 중구  11140         NaN       194.0           161.1
# 2      158  서울특별시 용산구  11170         NaN       247.0           113.1
# 3      153  서울특별시 성동구  11200         NaN       242.0            84.8
# 4      143  서울특별시 광진구  11215         NaN       337.0            99.4
# ..     ...        ...    ...         ...         ...             ...
# 177     60   경상남도 고성군  48820         NaN       179.0           353.4
# 178     62   경상남도 남해군  48840         NaN       155.0           365.6
# 179     78   경상남도 함양군  48870         NaN       142.0           369.4
# 180     59   경상남도 거창군  48880         NaN       154.0           252.5
# 181     79   경상남도 합천군  48890         NaN       172.0           399.0
#
#      순환계통 연령 표준화 사망률(10만명당)  운수사고 사망자 수  운수사고 10만명당 사망률  \
# 0                      64.5         7.0             4.9
# ...

# %%
df_final = pd.read_csv('/Users/phr/Desktop/BigTeam/big_final/data/표준화final.csv', encoding='utf-8')

# %%
df_final
# Out:
#           행정구역  sig_cd  진짜 구급차 출동시간 표준화  기대수명 표준화  병원수 표준화  보건시설 표준화  \
# 0    서울특별시 종로구   11110         1.000000  0.708333    0.125  0.087670
# 1     서울특별시 중구   11140         1.000000  0.716346    0.100  0.049388
# 2    서울특별시 용산구   11170         1.000000  0.767628    0.050  0.281052
# 3    서울특별시 성동구   11200         1.000000  0.719551    0.125  0.258234
# 4    서울특별시 광진구   11215         1.000000  0.674679    0.125  0.219497
# ..         ...     ...              ...       ...      ...       ...
# 177   경상남도 고성군   48820         0.853260  0.084936    0.025  0.719289
# 178   경상남도 남해군   48840         0.764298  0.213141    0.000  0.712201
# 179   경상남도 함양군   48870         0.851839  0.278846    0.000  0.621840
# 180   경상남도 거창군   48880         0.845561  0.376603    0.050  0.545313
# 181   경상남도 합천군   48890         0.713657  0.125000    0.000  0.691885
#
#       구급차 표준화   의사수 표준화  지방소멸지수 표준화
# 0    0.384615  1.000000    0.533190
# 1    0.230769  0.457711    0.554715
# ...

# %%
df_final['지역별중증사망수치'] = df3['지역별중증사망수치']

# %%
df_final
# Out:
#           행정구역  sig_cd  진짜 구급차 출동시간 표준화  기대수명 표준화  병원수 표준화  보건시설 표준화  \
# 0    서울특별시 종로구   11110         1.000000  0.708333    0.125  0.087670
# 1     서울특별시 중구   11140         1.000000  0.716346    0.100  0.049388
# 2    서울특별시 용산구   11170         1.000000  0.767628    0.050  0.281052
# 3    서울특별시 성동구   11200         1.000000  0.719551    0.125  0.258234
# 4    서울특별시 광진구   11215         1.000000  0.674679    0.125  0.219497
# ..         ...     ...              ...       ...      ...       ...
# 177   경상남도 고성군   48820         0.853260  0.084936    0.025  0.719289
# 178   경상남도 남해군   48840         0.764298  0.213141    0.000  0.712201
# 179   경상남도 함양군   48870         0.851839  0.278846    0.000  0.621840
# 180   경상남도 거창군   48880         0.845561  0.376603    0.050  0.545313
# 181   경상남도 합천군   48890         0.713657  0.125000    0.000  0.691885
#
#       구급차 표준화   의사수 표준화  지방소멸지수 표준화  지역별중증사망수치
# 0    0.384615  1.000000    0.533190      173.0
# ...

# %%
df_final.to_csv('./final_data.csv')

# %%
df_final.columns
# Out:
# Index(['행정구역', 'sig_cd', '진짜 구급차 출동시간 표준화', '기대수명 표준화', '병원수 표준화', '보건시설 표준화',
#        '구급차 표준화', '의사수 표준화', '지방소멸지수 표준화', '지역별중증사망수치'],
#       dtype='object')

# %%
column_indices = ['진짜 구급차 출동시간 표준화', '기대수명 표준화', '병원수 표준화', '보건시설 표준화',
       '구급차 표준화', '의사수 표준화', '지방소멸지수 표준화', '지역별중증사망수치']

# %%
column_indices
# Out:
# ['진짜 구급차 출동시간 표준화',
#  '기대수명 표준화',
#  '병원수 표준화',
#  '보건시설 표준화',
#  '구급차 표준화',
#  '의사수 표준화',
#  '지방소멸지수 표준화',
#  '지역별중증사망수치']

# %%
correlation = df_final[column_indices].corr()

# %%
print(correlation)
# Out:
#                  진짜 구급차 출동시간 표준화  기대수명 표준화   병원수 표준화  보건시설 표준화   구급차 표준화  \
# 진짜 구급차 출동시간 표준화         1.000000  0.316558  0.273364 -0.375482 -0.346761
# 기대수명 표준화                0.316558  1.000000  0.433065 -0.670056  0.058016
# 병원수 표준화                 0.273364  0.433065  1.000000 -0.623187  0.360629
# 보건시설 표준화               -0.375482 -0.670056 -0.623187  1.000000 -0.148327
# 구급차 표준화                -0.346761  0.058016  0.360629 -0.148327  1.000000
# 의사수 표준화                 0.266790  0.432631  0.285555 -0.487888  0.016239
# 지방소멸지수 표준화              0.289177  0.682463  0.579664 -0.834648  0.153211
# 지역별중증사망수치              -0.214740 -0.595135 -0.516977  0.738802 -0.240178
#
#                   의사수 표준화  지방소멸지수 표준화  지역별중증사망수치
# 진짜 구급차 출동시간 표준화  0.266790    0.289177  -0.214740
# 기대수명 표준화         0.432631    0.682463  -0.595135
# 병원수 표준화          0.285555    0.579664  -0.516977
# 보건시설 표준화        -0.487888   -0.834648   0.738802
# 구급차 표준화          0.016239    0.153211  -0.240178
# ...

# %%
df_love = pd.DataFrame()

# %%
df_love['지역별중증사망수치'] = df_final['지역별중증사망수치']

# %%
df_love
# Out:
#      지역별중증사망수치
# 0        173.0
# 1        172.7
# 2        121.8
# 3         95.7
# 4        107.6
# ..         ...
# 177      381.0
# 178      403.3
# 179      418.8
# 180      285.3
# 181      450.0
#
# [182 rows x 1 columns]

# %%
df_love.to_csv('./deathbaby.csv')

# %%
final_emci = df_final

# %%
final_emci
# Out:
#           행정구역  sig_cd  진짜 구급차 출동시간 표준화  기대수명 표준화  병원수 표준화  보건시설 표준화  \
# 0    서울특별시 종로구   11110         1.000000  0.708333    0.125  0.087670
# 1     서울특별시 중구   11140         1.000000  0.716346    0.100  0.049388
# 2    서울특별시 용산구   11170         1.000000  0.767628    0.050  0.281052
# 3    서울특별시 성동구   11200         1.000000  0.719551    0.125  0.258234
# 4    서울특별시 광진구   11215         1.000000  0.674679    0.125  0.219497
# ..         ...     ...              ...       ...      ...       ...
# 177   경상남도 고성군   48820         0.853260  0.084936    0.025  0.719289
# 178   경상남도 남해군   48840         0.764298  0.213141    0.000  0.712201
# 179   경상남도 함양군   48870         0.851839  0.278846    0.000  0.621840
# 180   경상남도 거창군   48880         0.845561  0.376603    0.050  0.545313
# 181   경상남도 합천군   48890         0.713657  0.125000    0.000  0.691885
#
#       구급차 표준화   의사수 표준화  지방소멸지수 표준화  지역별중증사망수치
# 0    0.384615  1.000000    0.533190      173.0
# ...

# %%
final_emci.columns
# Out:
# Index(['행정구역', 'sig_cd', '진짜 구급차 출동시간 표준화', '기대수명 표준화', '병원수 표준화', '보건시설 표준화',
#        '구급차 표준화', '의사수 표준화', '지방소멸지수 표준화', '지역별중증사망수치'],
#       dtype='object')

# %%
# 지역별 중증사망수치 표준화해서 상관관계 분석

# %%
df_add = pd.read_csv('/Users/phr/Desktop/BigTeam/big_final/data/deathbaby_transforemed.csv', encoding='cp949')

# %%
df_add
# Out:
#      지역별 중증사망수치 표준화 (1에서 뺀값)
# 0                   0.731625
# 1                   0.732350
# 2                   0.855416
# 3                   0.918520
# 4                   0.889749
# ..                       ...
# 174                 0.228723
# 175                 0.174807
# 176                 0.137331
# 177                 0.460106
# 178                 0.061896
#
# [179 rows x 1 columns]

# %%
df_final['정규화사망수치'] = df_add['지역별 중증사망수치 표준화 (1에서 뺀값)']

# %%
df_final
# Out:
#           행정구역  sig_cd  진짜 구급차 출동시간 표준화  기대수명 표준화  병원수 표준화  보건시설 표준화  \
# 0    서울특별시 종로구   11110         1.000000  0.708333    0.125  0.087670
# 1     서울특별시 중구   11140         1.000000  0.716346    0.100  0.049388
# 2    서울특별시 용산구   11170         1.000000  0.767628    0.050  0.281052
# 3    서울특별시 성동구   11200         1.000000  0.719551    0.125  0.258234
# 4    서울특별시 광진구   11215         1.000000  0.674679    0.125  0.219497
# ..         ...     ...              ...       ...      ...       ...
# 177   경상남도 고성군   48820         0.853260  0.084936    0.025  0.719289
# 178   경상남도 남해군   48840         0.764298  0.213141    0.000  0.712201
# 179   경상남도 함양군   48870         0.851839  0.278846    0.000  0.621840
# 180   경상남도 거창군   48880         0.845561  0.376603    0.050  0.545313
# 181   경상남도 합천군   48890         0.713657  0.125000    0.000  0.691885
#
#       구급차 표준화   의사수 표준화  지방소멸지수 표준화  지역별중증사망수치   정규화사망수치
# 0    0.384615  1.000000    0.533190      173.0  0.731625
# ...

# %%
column_indices2 = ['진짜 구급차 출동시간 표준화', '기대수명 표준화', '병원수 표준화', '보건시설 표준화',
       '구급차 표준화', '의사수 표준화', '지방소멸지수 표준화', '정규화사망수치']

# %%
corrr = df_final[column_indices2].corr()

# %%
print(corrr)
# Out:
#                  진짜 구급차 출동시간 표준화  기대수명 표준화   병원수 표준화  보건시설 표준화   구급차 표준화  \
# 진짜 구급차 출동시간 표준화         1.000000  0.316558  0.273364 -0.375482 -0.346761
# 기대수명 표준화                0.316558  1.000000  0.433065 -0.670056  0.058016
# 병원수 표준화                 0.273364  0.433065  1.000000 -0.623187  0.360629
# 보건시설 표준화               -0.375482 -0.670056 -0.623187  1.000000 -0.148327
# 구급차 표준화                -0.346761  0.058016  0.360629 -0.148327  1.000000
# 의사수 표준화                 0.266790  0.432631  0.285555 -0.487888  0.016239
# 지방소멸지수 표준화              0.289177  0.682463  0.579664 -0.834648  0.153211
# 정규화사망수치                 0.219749  0.513941  0.522698 -0.575295  0.218108
#
#                   의사수 표준화  지방소멸지수 표준화   정규화사망수치
# 진짜 구급차 출동시간 표준화  0.266790    0.289177  0.219749
# 기대수명 표준화         0.432631    0.682463  0.513941
# 병원수 표준화          0.285555    0.579664  0.522698
# 보건시설 표준화        -0.487888   -0.834648 -0.575295
# 구급차 표준화          0.016239    0.153211  0.218108
# ...

# %%
final_emci
# Out:
#           행정구역  sig_cd  진짜 구급차 출동시간 표준화  기대수명 표준화  병원수 표준화  보건시설 표준화  \
# 0    서울특별시 종로구   11110         1.000000  0.708333    0.125  0.087670
# 1     서울특별시 중구   11140         1.000000  0.716346    0.100  0.049388
# 2    서울특별시 용산구   11170         1.000000  0.767628    0.050  0.281052
# 3    서울특별시 성동구   11200         1.000000  0.719551    0.125  0.258234
# 4    서울특별시 광진구   11215         1.000000  0.674679    0.125  0.219497
# ..         ...     ...              ...       ...      ...       ...
# 177   경상남도 고성군   48820         0.853260  0.084936    0.025  0.719289
# 178   경상남도 남해군   48840         0.764298  0.213141    0.000  0.712201
# 179   경상남도 함양군   48870         0.851839  0.278846    0.000  0.621840
# 180   경상남도 거창군   48880         0.845561  0.376603    0.050  0.545313
# 181   경상남도 합천군   48890         0.713657  0.125000    0.000  0.691885
#
#       구급차 표준화   의사수 표준화  지방소멸지수 표준화  지역별중증사망수치   정규화사망수치
# 0    0.384615  1.000000    0.533190      173.0  0.731625
# ...

# %%
final_emci.columns
# Out:
# Index(['행정구역', 'sig_cd', '진짜 구급차 출동시간 표준화', '기대수명 표준화', '병원수 표준화', '보건시설 표준화',
#        '구급차 표준화', '의사수 표준화', '지방소멸지수 표준화', '지역별중증사망수치', '정규화사망수치'],
#       dtype='object')

# %%
final_emci['진짜 구급차 출동시간 표준화'] = final_emci['진짜 구급차 출동시간 표준화']*8
final_emci['기대수명 표준화'] = final_emci['기대수명 표준화']*24
final_emci['병원수 표준화'] = final_emci['병원수 표준화']*20
final_emci['보건시설 표준화'] = final_emci['보건시설 표준화']*0
final_emci['구급차 표준화'] = final_emci['구급차 표준화']*8
final_emci['의사수 표준화'] = final_emci['의사수 표준화']*8
final_emci['지방소멸지수 표준화'] = final_emci['지방소멸지수 표준화']*32

# %%
final_emci
# Out:
#           행정구역  sig_cd  진짜 구급차 출동시간 표준화   기대수명 표준화  병원수 표준화  보건시설 표준화  \
# 0    서울특별시 종로구   11110         8.000000  17.000000      2.5       0.0
# 1     서울특별시 중구   11140         8.000000  17.192308      2.0       0.0
# 2    서울특별시 용산구   11170         8.000000  18.423077      1.0       0.0
# 3    서울특별시 성동구   11200         8.000000  17.269231      2.5       0.0
# 4    서울특별시 광진구   11215         8.000000  16.192308      2.5       0.0
# ..         ...     ...              ...        ...      ...       ...
# 177   경상남도 고성군   48820         6.826077   2.038462      0.5       0.0
# 178   경상남도 남해군   48840         6.114388   5.115385      0.0       0.0
# 179   경상남도 함양군   48870         6.814715   6.692308      0.0       0.0
# 180   경상남도 거창군   48880         6.764485   9.038462      1.0       0.0
# 181   경상남도 합천군   48890         5.709260   3.000000      0.0       0.0
#
#       구급차 표준화   의사수 표준화  지방소멸지수 표준화  지역별중증사망수치   정규화사망수치
# 0    3.076923  8.000000   17.062067      173.0  0.731625
# ...

# %%
final_emci['emci'] = final_emci['진짜 구급차 출동시간 표준화'] + final_emci['기대수명 표준화'] + final_emci['병원수 표준화'] + final_emci['구급차 표준화']+ final_emci['의사수 표준화'] + final_emci['지방소멸지수 표준화']

# %%
final_emci
# Out:
#           행정구역  sig_cd  진짜 구급차 출동시간 표준화   기대수명 표준화  병원수 표준화  보건시설 표준화  \
# 0    서울특별시 종로구   11110         8.000000  17.000000      2.5       0.0
# 1     서울특별시 중구   11140         8.000000  17.192308      2.0       0.0
# 2    서울특별시 용산구   11170         8.000000  18.423077      1.0       0.0
# 3    서울특별시 성동구   11200         8.000000  17.269231      2.5       0.0
# 4    서울특별시 광진구   11215         8.000000  16.192308      2.5       0.0
# ..         ...     ...              ...        ...      ...       ...
# 177   경상남도 고성군   48820         6.826077   2.038462      0.5       0.0
# 178   경상남도 남해군   48840         6.114388   5.115385      0.0       0.0
# 179   경상남도 함양군   48870         6.814715   6.692308      0.0       0.0
# 180   경상남도 거창군   48880         6.764485   9.038462      1.0       0.0
# 181   경상남도 합천군   48890         5.709260   3.000000      0.0       0.0
#
#       구급차 표준화   의사수 표준화  지방소멸지수 표준화  지역별중증사망수치   정규화사망수치       emci
# ...

# %%
final_emci = final_emci.sort_values('emci')

# %%
final_emci = final_emci.reset_index(drop=True)

# %%
final_emci.head(30)
# Out:
#         행정구역  sig_cd  진짜 구급차 출동시간 표준화  기대수명 표준화  병원수 표준화  보건시설 표준화   구급차 표준화  \
# 0   전라남도 진도군   46900         6.893050  0.000000      0.5       0.0  1.846154
# 1   경상남도 합천군   48890         5.709260  3.000000      0.0       0.0  3.076923
# 2   경상남도 고성군   48820         6.826077  2.038462      0.5       0.0  1.846154
# 3   경상남도 의령군   48720         6.857969  4.115385      0.0       0.0  1.230769
# 4    강원도 철원군   42780         5.042618  0.115385      0.0       0.0  1.846154
# 5   경상북도 청도군   47820         6.509051  4.346154      0.5       0.0  1.230769
# 6   경상남도 남해군   48840         6.114388  5.115385      0.0       0.0  1.846154
# 7   경상남도 창녕군   48740         6.740168  2.307692      0.5       0.0  2.461538
# 8   충청북도 괴산군   43760         6.231889  3.461538      0.5       0.0  3.076923
# 9   경상북도 성주군   47840         6.926835  4.730769      0.0       0.0  1.230769
# 10   강원도 고성군   42820         6.224215  2.230769      2.0       0.0  1.230769
# ...

# %%
final_emci.to_csv('./emci_fianl_list')
