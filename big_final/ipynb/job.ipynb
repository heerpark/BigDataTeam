# %%
import pandas as pd

# %%
df_path = '/Users/phr/Desktop/BigTeam/big_final/data/3대중증 사망자.csv'
df = pd.read_csv(df_path, encoding='cp949')

# %%
df
# Out:
#               시군구별 순환계통 사망자수 운수사고 사망자수 낙상(추락) 사망자수 사망자수 합계
# 0            00 전국    62,370     3,624       2,722  68,716
# 1         11 서울특별시     9,350       367         423  10,140
# 2     　　　11010 종로구       229         7          11     247
# 3      　　　11020 중구       194         4          10     208
# 4     　　　11030 용산구       247         5          14     266
# ..             ...       ...       ...         ...     ...
# 297         39 제주도       760        52          29     841
# 298   　　　39010 제주시       551        32          18     601
# 299  　　　39020 서귀포시       209        20          11     240
# 300  　　　39310 북제주군       NaN       NaN         NaN       0
# 301  　　　39320 남제주군       NaN       NaN         NaN       0
#
# [302 rows x 5 columns]

# %%
before_list = list(df['시군구별'])

# %%
len(before_list)
# Out:
# 302

# %%
before_list
# Out:
# ['00 전국',
#  '11 서울특별시',
#  '\u3000\u3000\u300011010 종로구',
#  '\u3000\u3000\u300011020 중구',
#  '\u3000\u3000\u300011030 용산구',
#  '\u3000\u3000\u300011040 성동구',
#  '\u3000\u3000\u300011050 광진구',
#  '\u3000\u3000\u300011060 동대문구',
#  '\u3000\u3000\u300011070 중랑구',
#  '\u3000\u3000\u300011080 성북구',
#  '\u3000\u3000\u300011090 강북구',
#  '\u3000\u3000\u300011100 도봉구',
#  '\u3000\u3000\u300011110 노원구',
#  '\u3000\u3000\u300011120 은평구',
#  '\u3000\u3000\u300011130 서대문구',
#  '\u3000\u3000\u300011140 마포구',
#  '\u3000\u3000\u300011150 양천구',
#  '\u3000\u3000\u300011160 강서구',
#  '\u3000\u3000\u300011170 구로구',
#  '\u3000\u3000\u300011180 금천구',
#  '\u3000\u3000\u300011190 영등포구',
#  '\u3000\u3000\u300011200 동작구',
#  '\u3000\u3000\u300011210 관악구',
#  '\u3000\u3000\u300011220 서초구',
#  '\u3000\u3000\u300011230 강남구',
#  '\u3000\u3000\u300011240 송파구',
#  '\u3000\u3000\u300011250 강동구',
#  '21 부산광역시',
#  '\u3000\u3000\u300021010 중구',
#  '\u3000\u3000\u300021020 서구',
#  '\u3000\u3000\u300021030 동구',
# ...

# %%
raw_sig = []

# %%
a = before_list[3].split()

# %%
a[0]
# Out:
# '11020'

# %%
for i in before_list:
    data = i.split()
    data = int(data[0])
    raw_sig.append(data)

# %%
raw_sig
# Out:
# [0,
#  11,
#  11010,
#  11020,
#  11030,
#  11040,
#  11050,
#  11060,
#  11070,
#  11080,
#  11090,
#  11100,
#  11110,
#  11120,
#  11130,
#  11140,
#  11150,
#  11160,
#  11170,
#  11180,
#  11190,
#  11200,
#  11210,
#  11220,
#  11230,
#  11240,
#  11250,
#  21,
#  21010,
#  21020,
#  21030,
#  21040,
#  21050,
#  21060,
#  21070,
#  21080,
#  21090,
#  21100,
#  21110,
#  21120,
#  21130,
#  21140,
#  21150,
#  21310,
#  22,
#  22010,
#  22020,
#  22030,
#  22040,
#  22050,
#  22060,
#  22070,
#  22310,
#  23,
#  23010,
#  23020,
#  23030,
#  23040,
#  23050,
#  23060,
#  23070,
#  23080,
#  23090,
#  23310,
#  23320,
#  24,
#  24010,
#  24020,
#  24030,
#  24040,
#  24050,
#  25,
#  25010,
#  25020,
#  25030,
#  25040,
#  25050,
#  26,
#  26010,
#  26020,
#  26030,
#  26040,
#  26310,
#  29,
#  29010,
#  31,
#  31010,
#  31011,
#  31012,
#  31013,
#  31014,
#  31020,
#  31021,
#  31022,
#  31023,
#  31030,
#  31040,
#  31041,
#  31042,
#  31050,
#  31051,
#  31052,
#  31053,
# ...

# %%
sig = {"sig_cd":raw_sig}

# %%
df = df.assign(**sig)

# %%
df
# Out:
#               시군구별 순환계통 사망자수 운수사고 사망자수 낙상(추락) 사망자수 사망자수 합계  sig_cd
# 0            00 전국    62,370     3,624       2,722  68,716       0
# 1         11 서울특별시     9,350       367         423  10,140      11
# 2     　　　11010 종로구       229         7          11     247   11010
# 3      　　　11020 중구       194         4          10     208   11020
# 4     　　　11030 용산구       247         5          14     266   11030
# ..             ...       ...       ...         ...     ...     ...
# 297         39 제주도       760        52          29     841      39
# 298   　　　39010 제주시       551        32          18     601   39010
# 299  　　　39020 서귀포시       209        20          11     240   39020
# 300  　　　39310 북제주군       NaN       NaN         NaN       0   39310
# 301  　　　39320 남제주군       NaN       NaN         NaN       0   39320
#
# [302 rows x 6 columns]

# %%
df.to_csv('./3대사망자.csv')

# %%
df = pd.read_csv('emci_final_list.csv', encoding='utf-8')

# %%
df
# Out:
#      Unnamed: 0       행정구역  sig_cd  진짜 구급차 출동시간 표준화   기대수명 표준화  병원수 표준화  \
# 0             0   전라남도 진도군   46900         6.893050   0.000000      0.5
# 1             1   경상남도 합천군   48890         5.709260   3.000000      0.0
# 2             2   경상남도 고성군   48820         6.826077   2.038462      0.5
# 3             3   경상남도 의령군   48720         6.857969   4.115385      0.0
# 4             4    강원도 철원군   42780         5.042618   0.115385      0.0
# ..          ...        ...     ...              ...        ...      ...
# 177         177  서울특별시 서초구   11650         8.000000  24.000000      6.5
# 178         178  대전광역시 유성구   30200         7.898045  14.769231      7.0
# 179         179    경기도 화성시   41590         4.056160  13.000000      8.0
# 180         180  서울특별시 송파구   11710         8.000000  19.769231     11.5
# 181         181  서울특별시 강남구   11680         8.000000  22.961538     18.0
#
#      보건시설 표준화   구급차 표준화   의사수 표준화  지방소멸지수 표준화  지역별중증사망수치   정규화사망수치       emci
# ...

# %%
df.iloc[1,11] = 0.594872

# %%
df.iloc[0,4] = 0.403846154

# %%
df.head(10)
# Out:
#    Unnamed: 0      행정구역  sig_cd  진짜 구급차 출동시간 표준화  기대수명 표준화  병원수 표준화  보건시설 표준화  \
# 0           0  전라남도 진도군   46900         6.893050  0.403846      0.5       0.0
# 1           1  경상남도 합천군   48890         5.709260  3.000000      0.0       0.0
# 2           2  경상남도 고성군   48820         6.826077  2.038462      0.5       0.0
# 3           3  경상남도 의령군   48720         6.857969  4.115385      0.0       0.0
# 4           4   강원도 철원군   42780         5.042618  0.115385      0.0       0.0
# 5           5  경상북도 청도군   47820         6.509051  4.346154      0.5       0.0
# 6           6  경상남도 남해군   48840         6.114388  5.115385      0.0       0.0
# 7           7  경상남도 창녕군   48740         6.740168  2.307692      0.5       0.0
# 8           8  충청북도 괴산군   43760         6.231889  3.461538      0.5       0.0
# 9           9  경상북도 성주군   47840         6.926835  4.730769      0.0       0.0
#
#     구급차 표준화   의사수 표준화  지방소멸지수 표준화  지역별중증사망수치   정규화사망수치       emci
# ...

# %%
df.tail(10)
# Out:
#      Unnamed: 0        행정구역  sig_cd  진짜 구급차 출동시간 표준화   기대수명 표준화  병원수 표준화  \
# 172         172   서울특별시 관악구   11620         8.000000  14.807692      5.5
# 173         173   서울특별시 마포구   11440         8.000000  17.269231      2.0
# 174         174  서울특별시 영등포구   11560         8.000000  17.500000      7.5
# 175         175   광주광역시 광산구   29200         7.751342   8.615385     12.0
# 176         176   대구광역시 수성구   27290         7.995416  15.846154     20.0
# 177         177   서울특별시 서초구   11650         8.000000  24.000000      6.5
# 178         178   대전광역시 유성구   30200         7.898045  14.769231      7.0
# 179         179     경기도 화성시   41590         4.056160  13.000000      8.0
# 180         180   서울특별시 송파구   11710         8.000000  19.769231     11.5
# 181         181   서울특별시 강남구   11680         8.000000  22.961538     18.0
#
#      보건시설 표준화   구급차 표준화   의사수 표준화  지방소멸지수 표준화  지역별중증사망수치   정규화사망수치       emci
# 172       0.0  3.692308  0.477612   27.489988      119.4  0.861219  59.967600
# ...

# %%
df_output = df.drop('지역별중증사망수치', axis=1)

# %%
df_output
# Out:
#      Unnamed: 0       행정구역  sig_cd  진짜 구급차 출동시간 표준화   기대수명 표준화  병원수 표준화  \
# 0             0   전라남도 진도군   46900         6.893050   0.000000      0.5
# 1             1   경상남도 합천군   48890         5.709260   3.000000      0.0
# 2             2   경상남도 고성군   48820         6.826077   2.038462      0.5
# 3             3   경상남도 의령군   48720         6.857969   4.115385      0.0
# 4             4    강원도 철원군   42780         5.042618   0.115385      0.0
# ..          ...        ...     ...              ...        ...      ...
# 177         177  서울특별시 서초구   11650         8.000000  24.000000      6.5
# 178         178  대전광역시 유성구   30200         7.898045  14.769231      7.0
# 179         179    경기도 화성시   41590         4.056160  13.000000      8.0
# 180         180  서울특별시 송파구   11710         8.000000  19.769231     11.5
# 181         181  서울특별시 강남구   11680         8.000000  22.961538     18.0
#
#      보건시설 표준화   구급차 표준화   의사수 표준화  지방소멸지수 표준화   정규화사망수치       emci
# ...
