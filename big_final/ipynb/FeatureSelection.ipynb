# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df_path = '/Users/phr/Desktop/BigTeam/big_final/data/emci_analysis.csv'
state_data = pd.read_csv(df_path, encoding='utf-8')

# %%
state_data
# Out:
#      Unnamed: 0       행정구역  sig_cd 구급차출동시간   기대수명  병원수    보건시설  구급차   의사수  \
# 0             0  서울특별시 종로구   11110       0  85.31    6   48.22    7  21.1
# 1             1   서울특별시 중구   11140       0  85.36    5   38.12    5  10.2
# 2             2  서울특별시 용산구   11170       0  85.68    3   99.24    6   3.6
# 3             3  서울특별시 성동구   11200       0  85.38    6   93.22    4   3.6
# 4             4  서울특별시 광진구   11215       0  85.10    6   83.00    6   3.8
# ..          ...        ...     ...     ...    ...  ...     ...  ...   ...
# 177         177   경상남도 고성군   48820  11,779  81.42    2  214.86    5   1.8
# 178         178   경상남도 남해군   48840  18,920  82.22    1  212.99    5   1.7
# 179         179   경상남도 함양군   48870  11,893  82.63    1  189.15    6   1.8
# 180         180   경상남도 거창군   48880  12,397  83.24    3  168.96    6   2.0
# 181         181   경상남도 합천군   48890  22,985  81.67    1  207.63    7   2.2
#
#        지방소멸지수
# 0    0.758376
# 1    0.784802
# 2    0.920010
# 3    0.925891
# ...
